# %%
import torch
from torch.utils.tensorboard import SummaryWriter

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
#       <iframe id="tensorboard-frame-eeb297324844d958" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-eeb297324844d958");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Отже я взяв модель і зафайтюнив частково її на потрібних мені даних. По висновку я маю сейви в епохах по праним числам. починаючи з 6 епохи наше навчання давало гарний результат. Найкращий результат модель дала на 9 епосі і схоже вийшла на плато.
